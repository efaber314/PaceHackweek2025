# %%
from pathlib import Path

import cartopy.crs as ccrs
import earthaccess
import matplotlib.pyplot as plt
import numpy as np
import requests
import xarray as xr
from glob import glob
from datetime import datetime
import pdb
from datetime import datetime, timedelta
pip install global-land-mask
from global_land_mask import globe
# Out:
#   Cell In[70], line 15
#     pip install global-land-mask
#         ^
# SyntaxError: invalid syntax

# %%
def plot_l2_product(
    lon, lat, data, plot_range, label, title, vmin, vmax,fn, figsize=(12, 4), cmap="jet"):
    """Make map and histogram (default)."""

    # Create a figure with two subplots: 1 for map, 1 for histogram
    fig = plt.figure(figsize=figsize)
    gs = fig.add_gridspec(1, 2, width_ratios=[3, 1], wspace=0.3)

    # Map subplot
    ax_map = fig.add_subplot(gs[0], projection=ccrs.PlateCarree())
    ax_map.set_extent(plot_range, crs=ccrs.PlateCarree())
    ax_map.coastlines(resolution="110m", color="black", linewidth=0.8)
    ax_map.gridlines(draw_labels=True)
    ax_map.set_title(title, fontsize=12)

    # Assume lon and lat are defined globally or passed in
    for i in range(len(data)):
        pm = ax_map.pcolormesh(
            lon[i], lat[i], data[i], vmin=vmin, vmax=vmax, transform=ccrs.PlateCarree(), cmap=cmap
        )
    plt.colorbar(pm, ax=ax_map, orientation="vertical", pad=0.1, label=label)


    # Histogram subplot
    # ax_hist = fig.add_subplot(gs[1])
    # flattened_data = data[~np.isnan(data)]  # Remove NaNs for histogram
    # valid_count = np.sum(~np.isnan(flattened_data))
    # ax_hist.hist(
    #     flattened_data, bins=40, color="gray", range=[vmin, vmax], edgecolor="black"
    # )
    # ax_hist.set_xlabel(label)
    # ax_hist.set_ylabel("Count")
    # ax_hist.set_title("Histogram: N=" + str(valid_count))

    # plt.tight_layout()
    # plt.savefig(fn)
    plt.show()
    plt.clf()

# %%
target_date = datetime(2024,10,10)
oci_dir = '/home/jovyan/shared-public/DustBlumes/PACE_OCI_AOD/'
files = sorted(glob(oci_dir + target_date.strftime('*%Y%m%dT*')))
print(len(files))
# pdb.set_trace()
print(files)
aods = []
ssas = []
lons = []
lats = []
# Out:
# 5
# ['/home/jovyan/shared-public/DustBlumes/PACE_OCI_AOD/PACE_OCI.20241010T120137.L2.AER_UAA.V3_0.NRT.nc', '/home/jovyan/shared-public/DustBlumes/PACE_OCI_AOD/PACE_OCI.20241010T120637.L2.AER_UAA.V3_0.NRT.nc', '/home/jovyan/shared-public/DustBlumes/PACE_OCI_AOD/PACE_OCI.20241010T133454.L2.AER_UAA.V3_0.NRT.nc', '/home/jovyan/shared-public/DustBlumes/PACE_OCI_AOD/PACE_OCI.20241010T133954.L2.AER_UAA.V3_0.NRT.nc', '/home/jovyan/shared-public/DustBlumes/PACE_OCI_AOD/PACE_OCI.20241010T134454.L2.AER_UAA.V3_0.NRT.nc']

# %%
for file in files:

    datatree = xr.open_datatree(file)
    dataset = xr.merge(datatree.to_dict().values())
    lon = np.array(dataset['longitude'])
    lat = np.array(dataset['latitude'])
    aod = np.squeeze(np.array(dataset['Aerosol_Optical_Depth'][:,:,3]))
    # fmf = np.squeeze(np.array(dataset['Aerosol_Optical_Depth'][:,:,3]))
    ssa_388_dt = np.squeeze(np.array(dataset['DT_AerosolSingleScattAlbedo'][:,:,1]))
    ssa_388_nuv = np.squeeze(np.array(dataset['NUV_AerosolSingleScattAlbedo'][:,:,1]))

    lons.append(lon)
    lats.append(lat)
    aods.append(aod)
    ssas.append(ssa_388_nuv)

# %%
    
plot_range = [np.nanmin(lons), np.nanmax(lons), np.nanmin(lats), np.nanmax(lats)]
    
plot_l2_product(lons, lats, aods, plot_range=plot_range, label='', title=target_date.strftime('AOD_%Y%m%d'), vmin=0, vmax=2, fn=target_date.strftime('PACE_OCI_AOD_%Y%m%d.png'), cmap="jet")

# plot_l2_product(lon, lat,
# ssa_388_dt, plot_range=plot_range, label='', title='DT_SSA', vmin=0.7, vmax=1, 
#                 fn=target_date.strftime('PACE_OCI_DTSSA_%Y%m%d.png'), cmap="jet")

# %%
print(np.nanmean(aods))
# Out:
# 0.235409128847157

# %%
plot_l2_product(lons, lats, ssas, plot_range=plot_range, label='', title='NUV_SSA', vmin=0.7, vmax=1, fn=target_date.strftime('PACE_OCI_NUVSSA_%Y%m%d.png'), cmap="jet")

# %%
#date range 
target_date_range = np.arange(datetime(2024,9,24), datetime(2024,10,10), timedelta(days=1)).astype(datetime)

# %%
daily_AOD_avg = []
daily_AOD_anom_avg = []
daily_plume_mask = []
for day in target_date_range:
    files = sorted(glob(oci_dir + day.strftime('*%Y%m%dT*'))) 
    aods = []
    ssas = []
    lons = []
    lats = []

    for file in files:
        datatree = xr.open_datatree(file)
        dataset = xr.merge(datatree.to_dict().values())
        lon = np.array(dataset['longitude'])
        lat = np.array(dataset['latitude'])
        aod = np.squeeze(np.array(dataset['Aerosol_Optical_Depth'][:,:,3]))
        ssa_388_dt = np.squeeze(np.array(dataset['DT_AerosolSingleScattAlbedo'][:,:,1]))
        ssa_388_nuv = np.squeeze(np.array(dataset['NUV_AerosolSingleScattAlbedo'][:,:,1]))
        
        lons.append(lon)
        lats.append(lat)
        aods.append(aod)
        ssas.append(ssa_388_nuv)
        over_water_AOD = np.where(globe.is_land(lats,lons) == False, aods, np.nan)
        highs_over_water = np.where(over_water_AOD > 0.3, over_water_AOD, np.nan)
        plume_mask = np.where(highs_over_water > 0, 1, 0)
    daily_AOD_avg.append(np.nanmean(over_water_AOD))
    daily_AOD_anom_avg.append(np.nanmean(highs_over_water))
    daily_plume_mask.append(plume_mask)

print(len(daily_AOD_avg))
print(len(daily_plume_mask))
# Out:
# 16
# 16

# %%
plot_l2_product(lons, lats, daily_plume_mask[3], plot_range=plot_range, label='', title='over water aod', vmin = 0, vmax=1, fn=target_date.strftime('PACE_OCI_NUVSSA_%Y%m%d.png'), cmap="jet")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 plot_l2_product(lons, lats, daily_plume_mask[3], plot_range=plot_range, label='', title='over water aod', vmin = 0, vmax=1, fn=target_date.strftime('PACE_OCI_NUVSSA_%Y%m%d.png'), cmap="jet")
#
# Cell In[3], line 19, in plot_l2_product(lon, lat, data, plot_range, label, title, vmin, vmax, fn, figsize, cmap)
#      16 # Assume lon and lat are defined globally or passed in
#      17 for i in range(len(data)):
#      18     pm = ax_map.pcolormesh(
# ---> 19         lon[i], lat[i], data[i], vmin=vmin, vmax=vmax, transform=ccrs.PlateCarree(), cmap=cmap
#      20     )
#      21 plt.colorbar(pm, ax=ax_map, orientation="vertical", pad=0.1, label=label)
#      24 # Histogram subplot
#      25 # ax_hist = fig.add_subplot(gs[1])
#      26 # flattened_data = data[~np.isnan(data)]  # Remove NaNs for histogram
#    (...)
#      35 # plt.tight_layout()
#      36 # plt.savefig(fn)
#
# IndexError: list index out of range

# %%
#save the mask
print(plume_mask.shape)
print(len(lat), len(lon))
# reshaped = plume_mask.reshape()
# print(reshaped.shape)

# for day in daily_plume_mask:
#     merged_array = np.zeros([day.shape[1]*len(day),day.shape[2]*len(day)])
#     for i in range(1,len(day)+1): #this is how many swaths
#         for x in range(200, day.shape[1]):
#             for y in range(150, day.shape[2]):
#                 merged_array[x,y] = day[i*x,i*y]
#     print(merged_array.shape)
    
# import rasterio
# from rasterio.merge import merge
# merged_array, merged_transform = merge(daily_plume_mask)

# flat = plume_mask.flatten()
# df = xr.DataArray(flat, coords=[('lon', lons), ('lat', lats)])
# # df.to_array(dim="time").assign_coords(time=target_date_range)
# df.to_netcdf('Plume_mask_test.nc')
# Out:
# (10, 244, 181)
# 244 244

# %%
plt.plot(target_date_range,daily_AOD_anom_avg, label = 'OCI AOD')
plt.ylabel('PACE OCI AOD')
plt.xlabel('Dates')
plt.xticks(rotation = 45)
plt.title('Daily Average AOD Anomalies Over Water')
plt.legend()
